# %% [markdown]
# # Get Congress Members

# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
import os
from itertools import groupby
import numpy as np

# %% [markdown]
# ## Get Senate Members

# %%
url2 = 'https://www.senate.gov/general/committee_assignments/assignments.htm'
response2 = rq.get(url2)

soup2 = BeautifulSoup(response2.content,'html.parser')

gov_data = soup2.select('a')

actual_titles = []
for title in gov_data:
    if title.parent.name == 'div' or title.parent.name == 'strong':
        actual_titles.append(title.text.strip())

# %%
arr = np.array(actual_titles)
idx = np.where(arr == 'Back to top')[0]
subarrays = np.split(arr, idx+1)

result = [subarray.tolist() for subarray in subarrays if len(subarray) > 0]

filtered_result = [[item for item in sublist if item != '' and item != 'Back to top'] for sublist in result]

senators_committees = pd.DataFrame(filtered_result).rename(columns={0:'senator',1:'c1',2:'c2',3:'c3',4:'c4',5:'c5',6:'c6',7:'c7',8:'c8'})

senators_committees_csv = 'inputs/senators_committees.csv'

if not os.path.exists(senators_committees_csv):
    senators_committees.to_csv(senators_committees_csv,index=False)

# %%
senators = pd.read_csv('inputs/senators_committees.csv')
senators
# Out:
#                  senator                                                 c1  \
# 0         Baldwin, Tammy                        Committee on Appropriations
# 1         Barrasso, John          Committee on Energy and Natural Resources
# 2     Bennet, Michael F.  Committee on Agriculture, Nutrition, and Forestry
# 3      Blackburn, Marsha  Committee on Commerce, Science, and Transporta...
# 4    Blumenthal, Richard   Commission on Security and Cooperation in Europe
# ..                   ...                                                ...
# 96   Whitehouse, Sheldon   Commission on Security and Cooperation in Europe
# 97      Wicker, Roger F.   Commission on Security and Cooperation in Europe
# 98            Wyden, Ron          Committee on Energy and Natural Resources
# 99           Young, Todd  Committee on Commerce, Science, and Transporta...
# 100                  NaN                                                NaN
#
#                                                     c2  \
# 0    Committee on Commerce, Science, and Transporta...
# 1                                 Committee on Finance
# 2                                 Committee on Finance
# 3                                 Committee on Finance
# 4                          Committee on Armed Services
# ..                                                 ...
# 96           Committee on Environment and Public Works
# 97                         Committee on Armed Services
# 98                                Committee on Finance
# 99                                Committee on Finance
# 100                                                NaN
#
#                                                     c3  \
# 0    Committee on Health, Education, Labor, and Pen...
# 1                       Committee on Foreign Relations
# 2                Committee on Rules and Administration
# 3                           Committee on the Judiciary
# 4    Committee on Homeland Security and Governmenta...
# ..                                                 ...
# 96                                Committee on Finance
# 97   Committee on Commerce, Science, and Transporta...
# 98                             Committee on the Budget
# 99                      Committee on Foreign Relations
# 100                                                NaN
#
#                                                    c4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                    Select Committee on Intelligence
# 3                      Committee on Veterans' Affairs
# 4                          Committee on the Judiciary
# ..                                                ...
# 96                            Committee on the Budget
# 97          Committee on Environment and Public Works
# 98                        Joint Committee on Taxation
# 99   Committee on Small Business and Entrepreneurship
# 100                                               NaN
#
#                                         c5  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4           Committee on Veterans' Affairs
# ..                                     ...
# 96              Committee on the Judiciary
# 97   Committee on Rules and Administration
# 98        Select Committee on Intelligence
# 99                                     NaN
# 100                                    NaN
#
#                                                     c6  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                           Special Committee on Aging
# ..                                                 ...
# 96   United States Senate Caucus on International N...
# 97                    Select Committee on Intelligence
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
#
#                                                     c7   c8
# 0                                                  NaN  NaN
# 1                                                  NaN  NaN
# 2                                                  NaN  NaN
# 3                                                  NaN  NaN
# 4    United States Senate Caucus on International N...  NaN
# ..                                                 ...  ...
# 96                                                 NaN  NaN
# 97                                                 NaN  NaN
# 98                                                 NaN  NaN
# 99                                                 NaN  NaN
# 100                                                NaN  NaN
#
# [101 rows x 9 columns]

# %% [markdown]
# ## Get gsectors

# %%
url3 = 'https://en.wikipedia.org/wiki/Global_Industry_Classification_Standard'
response3 = rq.get(url3)

soup3 = BeautifulSoup(response3.content,'html.parser')

gsect = soup3.select('table')
gsect = pd.read_html(str(gsect))
gsect = pd.DataFrame(gsect[0])

# %%
gsect
# Out:
#      Sector     Sector.1  Industry Group  \
# 0        10       Energy            1010
# 1        10       Energy            1010
# 2        10       Energy            1010
# 3        10       Energy            1010
# 4        10       Energy            1010
# ..      ...          ...             ...
# 159      60  Real Estate            6010
# 160      60  Real Estate            6020
# 161      60  Real Estate            6020
# 162      60  Real Estate            6020
# 163      60  Real Estate            6020
#
#                                  Industry Group.1  Industry  \
# 0                                          Energy  101010.0
# 1                                          Energy  101010.0
# 2                                          Energy  101020.0
# 3                                          Energy  101020.0
# 4                                          Energy  101020.0
# ..                                            ...       ...
# 159  Equity Real Estate Investment Trusts (REITs)  601080.0
# 160          Real Estate Management & Development  602010.0
# 161          Real Estate Management & Development  602010.0
# 162          Real Estate Management & Development  602010.0
# 163          Real Estate Management & Development  602010.0
#
#                                Industry.1  Sub-Industry  \
# 0             Energy Equipment & Services    10101010.0
# 1             Energy Equipment & Services    10101020.0
# 2             Oil, Gas & Consumable Fuels    10102010.0
# 3             Oil, Gas & Consumable Fuels    10102020.0
# 4             Oil, Gas & Consumable Fuels    10102030.0
# ..                                    ...           ...
# 159                     Specialized REITs    60108050.0
# 160  Real Estate Management & Development    60201010.0
# 161  Real Estate Management & Development    60201020.0
# 162  Real Estate Management & Development    60201030.0
# 163  Real Estate Management & Development    60201040.0
#
#                          Sub-Industry.1
# 0                    Oil & Gas Drilling
# 1        Oil & Gas Equipment & Services
# 2                  Integrated Oil & Gas
# 3    Oil & Gas Exploration & Production
# 4        Oil & Gas Refining & Marketing
# ..                                  ...
# 159                   Data Center REITs
# 160  Diversified Real Estate Activities
# 161     Real Estate Operating Companies
# 162             Real Estate Development
# 163                Real Estate Services
#
# [164 rows x 8 columns]
